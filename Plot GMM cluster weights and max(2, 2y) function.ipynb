# %%
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import numpy as np
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
N = 100
x, y = np.meshgrid(np.linspace(-10, 10, N), np.linspace(-10, 10, N))

# %%
# z = f(x, y) = max(2, 2y)
z = np.max([2*np.ones_like(x), 2*y], axis=0)

# %%
iplot([dict(x=x, y=y, z=z, type='surface')])
# Out:
# <div id="b3ff8fec-4980-496e-9637-4bdcd37fb2d7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b3ff8fec-4980-496e-9637-4bdcd37fb2d7", [{"x": [[-10.0, -9.797979797979798, -9.595959595959595, -9.393939393939394, -9.191919191919192, -8.98989898989899, -8.787878787878787, -8.585858585858587, -8.383838383838384, -8.181818181818182, -7.979797979797979, -7.777777777777778, -7.575757575757576, -7.373737373737374, -7.171717171717171, -6.96969696969697, -6.767676767676768, -6.565656565656566, -6.363636363636363, -6.161616161616162, -5.959595959595959, -5.757575757575758, -5.555555555555555, -5.353535353535354, -5.151515151515151, -4.94949494949495, -4.747474747474747, -4.545454545454546, -4.343434343434343, -4.141414141414142, -3.9393939393939394, -3.737373737373738, -3.5353535353535355, -3.333333333333333, 
# ...

# %% [markdown]
# # Plot of GMM cluster weights
# Copy-pasted from a console dump of the weights of a learned imputation GMM.

# %%
w = np.array([  2.19594216e-01,   1.98182828e-02,   1.96214925e-03,
         1.49626555e-01,   1.95081819e-03,   1.88412941e-01,
         1.93557835e-03,   3.33632845e-02,   1.91699448e-03,
         1.90740798e-03,   1.89786943e-03,   1.88837857e-03,
         3.41463885e-02,   3.32117089e-01,   1.56052717e-03,
         1.30320653e-03,   1.08831637e-03,   9.08860183e-04,
         4.56499448e-03,   3.61426252e-05])
iplot([dict(y=sorted(w, key=lambda k: -k))])
# Out:
# <div id="a100b41f-7057-4358-9549-68fd8f1bdd44" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a100b41f-7057-4358-9549-68fd8f1bdd44", [{"y": [0.332117089, 0.219594216, 0.188412941, 0.149626555, 0.0341463885, 0.0333632845, 0.0198182828, 0.00456499448, 0.00196214925, 0.00195081819, 0.00193557835, 0.00191699448, 0.00190740798, 0.00189786943, 0.00188837857, 0.00156052717, 0.00130320653, 0.00108831637, 0.000908860183, 3.61426252e-05]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
w_i = np.argsort(w)[::-1]
mask = np.zeros_like(w, dtype=np.bool)
mask[w_i] = np.cumsum(w[w_i]) < 0.99
mask, w_i
# Out:
# (array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False, False, False,  True,  True, False, False, False, False,
#          True, False], dtype=bool),
#  array([13,  0,  5,  3, 12,  7,  1, 18,  2,  4,  6,  8,  9, 10, 11, 14, 15,
#         16, 17, 19]))
